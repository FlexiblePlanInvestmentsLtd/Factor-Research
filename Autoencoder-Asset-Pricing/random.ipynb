# %%
import pickle

with open('../data/datashare.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
import os
import zipfile
from joblib import delayed, Parallel
from itertools import product
from utils import CHARAS_LIST
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# os.system('wget https://cloud.tsinghua.edu.cn/f/07d6a0223d054247af26/?dl=1 -O data.zip')

with zipfile.ZipFile('data.zip', 'r') as z:
    with z.open('data/datashare.pkl') as f:
        print('Reading datashare.pkl', end=' ')
        datashare = pd.read_pickle(f)
        display(datashare.tail())
# Out:
# --2025-03-18 22:57:38--  https://cloud.tsinghua.edu.cn/f/07d6a0223d054247af26/?dl=1
# Resolving cloud.tsinghua.edu.cn (cloud.tsinghua.edu.cn)... 101.6.15.69, 2402:f000:1:402:101:6:15:69
# Connecting to cloud.tsinghua.edu.cn (cloud.tsinghua.edu.cn)|101.6.15.69|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cloud.tsinghua.edu.cn/seafhttp/files/90d2d69a-08b3-4ecc-9037-12c3e6502a89/new_data.zip [following]
# --2025-03-18 22:57:39--  https://cloud.tsinghua.edu.cn/seafhttp/files/90d2d69a-08b3-4ecc-9037-12c3e6502a89/new_data.zip
# Reusing existing connection to cloud.tsinghua.edu.cn:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1604297079 (1.5G) [application/zip]
# Saving to: ‘data.zip’
#
#      0K .......... .......... .......... .......... ..........  0%  114K 3h49m
#     50K .......... .......... .......... .......... ..........  0%  250K 2h47m
#    100K .......... .......... .......... .......... ..........  0%  354K 2h15m
# ...

# %%
with zipfile.ZipFile('datashare.zip', 'r') as z:
    with z.open('datashare.csv') as f:
        print('Reading datashare.pkl', end=' ')
        datashare = pd.read_csv(f)
        display(datashare.tail())
# Out:
# Reading datashare.pkl
#          permno      DATE         mvel1      beta    betasq     chmom  \
# 4117295   93423  20211231  3.144398e+06  1.923076  3.698221 -0.673385
# 4117296   93426  20211231  4.326610e+05  1.224523  1.499457 -0.061462
# 4117297   93427  20211231  4.092710e+06  0.887083  0.786917 -0.080295
# 4117298   93434  20211231  1.130478e+05  0.512942  0.263110 -0.543760
# 4117299   93436  20211231  1.149642e+09  1.504264  2.262812  0.729456
#
#             dolvol   idiovol    indmom     mom1m  ...     stdcf   ms  \
# 4117295  16.305232  0.062619  0.491455 -0.110868  ...  0.960494  3.0
# 4117296  12.419552  0.033723  0.346308  0.007040  ...  0.050973  6.0
# 4117297  14.884834  0.045395  0.346308  0.151667  ...  0.052512  6.0
# 4117298  12.243872  0.088124  0.270005 -0.319347  ...  0.556876  2.0
# 4117299  18.992410  0.081092  0.223504  0.027612  ...  0.181713  6.0
#
#          baspread           ill    maxret    retvol  std_dolvol   std_turn  \
# ...

# %%
datashare[datashare['DATE'] >= 201701]
# Out:
#          permno      DATE         mvel1      beta    betasq     chmom  \
# 0         10006  19570131  8.224900e+04  1.122846  1.260784  0.047180
# 1         10014  19570131  3.903375e+03  0.426734  0.182102 -0.275641
# 2         10022  19570131  9.273250e+03  1.066449  1.137313 -0.025490
# 3         10030  19570131  5.446588e+04  0.926038  0.857547  0.018171
# 4         10057  19570131  4.025000e+04  1.247748  1.556875  0.025785
# ...         ...       ...           ...       ...       ...       ...
# 4117295   93423  20211231  3.144398e+06  1.923076  3.698221 -0.673385
# 4117296   93426  20211231  4.326610e+05  1.224523  1.499457 -0.061462
# 4117297   93427  20211231  4.092710e+06  0.887083  0.786917 -0.080295
# 4117298   93434  20211231  1.130478e+05  0.512942  0.263110 -0.543760
# 4117299   93436  20211231  1.149642e+09  1.504264  2.262812  0.729456
#
#             dolvol   idiovol    indmom     mom1m  ...     stdcf   ms  \
# ...

# %%
a = pd.read_pickle('data/mon_list.pkl')

# %%
a[a>20170131]
# Out:
# 721    20170228
# 722    20170331
# 723    20170428
# 724    20170531
# 725    20170630
# 726    20170731
# 727    20170831
# 728    20170929
# 729    20171031
# 730    20171130
# 731    20171229
# 732    20180131
# 733    20180228
# 734    20180329
# 735    20180430
# 736    20180531
# 737    20180629
# 738    20180731
# 739    20180831
# 740    20180928
# 741    20181031
# 742    20181130
# 743    20181231
# 744    20190131
# 745    20190228
# 746    20190329
# 747    20190430
# 748    20190531
# 749    20190628
# 750    20190731
# 751    20190830
# 752    20190930
# 753    20191031
# 754    20191129
# 755    20191231
# 756    20200131
# 757    20200228
# 758    20200331
# 759    20200430
# 760    20200529
# 761    20200630
# 762    20200731
# 763    20200831
# 764    20200930
# 765    20201030
# 766    20201130
# 767    20201231
# 768    20210129
# 769    20210226
# 770    20210331
# 771    20210430
# 772    20210528
# 773    20210630
# 774    20210730
# 775    20210831
# ...

# %%
a = pd.read_pickle('data/p_charas.pkl')
b = pd.read_pickle('data/p_charas_2.pkl')
c = pd.concat([a, b])
c.shape
# Out:
# (73132, 95)

# %%
c.to_pickle('data/p_charas.pkl')
