# %%
import pandas as pd
from eodhd import APIClient
import sys
sys.path.insert(0, "../src/")
from Features import technical_features
import talib

# %%
obj = technical_features.BuildFeatures('MSFT')

# %%
obj.stock.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 1986-03-13 00:00:00-05:00 0.05448535 0.06249798 0.05448535 0.05982669
# 1986-03-14 00:00:00-05:00 0.05982675 0.06303217 0.05982675 0.06196329
# 1986-03-17 00:00:00-05:00 0.06196329 0.06356631 0.06196329 0.06303217
# 1986-03-18 00:00:00-05:00 0.06303211 0.06356624 0.06089496 0.06142909
# 1986-03-19 00:00:00-05:00 0.06142916 0.06196329 0.05982676 0.06036089
#
#                                Volume  Dividends  Stock Splits
# Date
# 1986-03-13 00:00:00-05:00  1031788800 0.00000000    0.00000000
# 1986-03-14 00:00:00-05:00   308160000 0.00000000    0.00000000
# 1986-03-17 00:00:00-05:00   133171200 0.00000000    0.00000000
# 1986-03-18 00:00:00-05:00    67766400 0.00000000    0.00000000
# 1986-03-19 00:00:00-05:00    47894400 0.00000000    0.00000000

# %%
obj.build_technical_features()

# %%
obj.technical_features.tail()
# Out:
#                                 SMA_50      SMA_200     Chaikin_ADI_Line  \
# Date
# 2025-01-17 00:00:00-05:00 428.51676453 423.98321686 12633056769.02912331
# 2025-01-21 00:00:00-05:00 428.87400391 424.03521179 12635517689.79148865
# 2025-01-22 00:00:00-05:00 429.41119202 424.18848511 12658042084.26582527
# 2025-01-23 00:00:00-05:00 429.85378906 424.30632172 12676151106.50006104
# 2025-01-24 00:00:00-05:00 430.30107056 424.41553238 12676358356.18267822
#
#                            Chaikin_ADI_Oscillator   ADM_Index  \
# Date
# 2025-01-17 00:00:00-05:00       -7538306.92732811 19.79282916
# 2025-01-21 00:00:00-05:00       -8952680.43404388 18.71150250
# 2025-01-22 00:00:00-05:00       -1550554.95095253 18.87998803
# 2025-01-23 00:00:00-05:00        7380508.45310974 19.03643888
# 2025-01-24 00:00:00-05:00       10429113.06714058 19.16668006
#
#                            ADM_Index_Rating  Absolute_Price_Oscillator Aroon  \
# Date
# ...
