# %%
import pandas as pd
import warnings
import numpy as np

warnings.filterwarnings("ignore")

# %% [markdown]
# Get Technical Features

# %%
sp1500 = pd.read_excel("../data/SPR as of Feb 12 20251.xlsx")
tickers = sp1500['Ticker'].str.split(" ").str[0]

# %%
import sys
import os

# Get the absolute path of the project's root directory
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))  # Get the parent directory of the current working directory

# Construct the path to the `src` directory
src_path = os.path.join(project_root, "src")

# Add the `src` directory to the Python module search path
sys.path.append(src_path)

# %%
import importlib
from Features import technical_features_new

importlib.reload(technical_features_new)
from Features.technical_features_new import BuildFeatures

# %%
# Generate all NYSE trading days from 1980 to 2025
all_dates = pd.bdate_range(start="1980-01-01", end="2025-02-24", freq="B") 
date_to_qid = {date: qid for qid, date in enumerate(all_dates)}

# %%
import pickle as pkl
import gzip
from tqdm import tqdm

# Define storage path
cache_path = "../data/technical_features"

# Ensure the directory exists
os.makedirs(cache_path, exist_ok=True)

# Process stock data
for tick in tqdm(tickers, desc="Processing Tickers", unit="ticker"):
    try:
        obj = BuildFeatures(tick)
    except:
        continue
    
    obj.build_technical_features()  # Compute technical indicators
    data = obj.technical_features.copy()
        
    if data.empty:
        continue
    
    data["Close"] = obj.stock["Close"]
    data = data.resample('BM').last()
    data["Return"] = data["Close"].pct_change().shift(-1).astype(np.float32)

    # Define file path
    file_path = os.path.join(cache_path, f"{tick}.pkl.gz")

    # Save the data using gzip compression to reduce file size
    with gzip.open(file_path, "wb") as f:
        pkl.dump(data, f, protocol=pkl.HIGHEST_PROTOCOL)

print("✅ All data has been successfully stored and optimized with compression!")
# Out:
# Processing Tickers: 100%|██████████| 1506/1506 [22:14<00:00,  1.13ticker/s]
# ✅ All data has been successfully stored and optimized with compression!

# %%
import importlib
from Features import fundamental_features_new

importlib.reload(fundamental_features_new)
from Features.fundamental_features_new import BuildFeatures as BuildFundamentalFeatures

# %%
zacks_fc = pd.read_csv("../data/fundamental_data/ZACKS_FC.csv", delimiter=',')
zacks_fc['per_end_date'] = pd.to_datetime(zacks_fc['per_end_date'])
zacks_fc['per_end_date'] = zacks_fc['per_end_date'].dt.tz_localize('US/Eastern')
zacks_fc = zacks_fc.sort_values('per_end_date').set_index('per_end_date')

zacks_fr = pd.read_csv("../data/fundamental_data/ZACKS_FR.csv", delimiter=',')
zacks_fr['per_end_date'] = pd.to_datetime(zacks_fr['per_end_date'])
zacks_fr['per_end_date'] = zacks_fr['per_end_date'].dt.tz_localize('US/Eastern')
zacks_fr = zacks_fr.sort_values('per_end_date').set_index('per_end_date')

zack_data = {}
zack_data["zacks_fc"] = zacks_fc
zack_data["zacks_fr"] = zacks_fr

# %%
from tqdm import tqdm
import pickle as pkl
import gzip

# Define storage path
cache_path = "../data/fundamental_features"

# Ensure the directory exists
os.makedirs(cache_path, exist_ok=True)

for tick in tqdm(tickers, desc="Processing Tickers", unit="ticker"):

    try:
        obj = BuildFundamentalFeatures(zack_data, tick)
    except:
        continue

    obj.process_financial_statements()  # Generate technical features for the ticker
    
    # Merge technical features with the calculated returns
    data = obj.fundamental_features.copy()
    
    if data.empty:
        continue

    data = data[data['per_type'] == 'Q']
    data['filing_date'] = pd.to_datetime(data['filing_date'])
    data.index.name = 'report_date'
    data = data.reset_index()
    
    data = data.set_index('filing_date')
    data['filing_date'] = data.index
    try:
        full_date_range = pd.date_range(start=data.index.min(), end=data.index.max(), freq="D")
    except:
        continue
    
    data = data.drop_duplicates(subset="filing_date", keep="last")
    data = data.reindex(full_date_range)
    data = data.ffill().resample('BM').last()
    
    data["Close"] = obj.stock['Close']
    
    data["Return"] = data["Close"].pct_change().shift(-1)
    
    # Define file path
    file_path = os.path.join(cache_path, f"{tick}.pkl.gz")

    # Save the data using gzip compression to reduce file size
    with gzip.open(file_path, "wb") as f:
        pkl.dump(data, f, protocol=pkl.HIGHEST_PROTOCOL)

print("✅ All data has been successfully stored and optimized with compression!")
# Out:
# Processing Tickers:  10%|█         | 151/1506 [01:48<21:54,  1.03ticker/s]

# %%
from tqdm import tqdm
import gzip
import pickle as pkl
import numpy as np
import pandas as pd
import os

# Set cutoff dates for training, validation, and test sets
train_cutoff = "2014-01-01"
valid_cutoff = "2018-01-01"

# Paths
data_path_tech = "../data/technical_features"
data_path_fin = "../data/fundamental_features"

# List to store all data
all_data = []

# Process all tickers
for tick in tqdm(tickers, desc="Processing Tickers", unit="ticker"):
    file_path_tech = os.path.join(data_path_tech, f"{tick}.pkl.gz")
    file_path_fin = os.path.join(data_path_fin, f"{tick}.pkl.gz")
    try:
        # Load technical data
        with gzip.open(file_path_tech, "rb") as f:
            tech_data = pkl.load(f)
            tech_data["Ticker"] = tick

        # Load fundamental data
        with gzip.open(file_path_fin, "rb") as f:
            fin_data = pkl.load(f)
            fin_data = fin_data.dropna(axis=1, how="all")
            fin_data = fin_data.select_dtypes(include=[float, int])  # Keep only numeric columns

        combined_data = tech_data.merge(fin_data, how="outer", left_index=True, right_index=True)
        combined_data['Return'] = combined_data['Return_x'].fillna(combined_data['Return_y'])
        combined_data = combined_data.drop(columns=['Return_x', 'Return_y'])
        combined_data = combined_data.dropna(subset=['Return'])
        combined_data = combined_data.ffill()
        combined_data.index.name = 'date'
    except:
        continue

    all_data.append(combined_data)

# Merge all data and sort by date
all_data_df = pd.concat(all_data).sort_index()
all_data_df = all_data_df.dropna(subset=["Return"])

# Define threshold for missing values
threshold = len(all_data_df) * 0.3
all_data_df = all_data_df.dropna(axis=1, thresh=threshold)
all_data_df = all_data_df.dropna()

# Assign qid values based on unique dates
unique_dates = all_data_df.index.unique()
date_to_qid = {date: i for i, date in enumerate(unique_dates)}
all_data_df["qid"] = all_data_df.index.map(date_to_qid).astype(np.int32)

# Compute quintile ranking for stock returns
def compute_ranked_labels(df):
    df["Ranked_Return"] = df.groupby("qid")["Return"].transform(
        lambda x: pd.qcut(x, 5, labels=False, duplicates="drop")  # 0-4 ranking
    ).astype(np.int32)
    return df

all_data_df = compute_ranked_labels(all_data_df)

# Split dataset
train_data = all_data_df[all_data_df.index < train_cutoff]
valid_data = all_data_df[(all_data_df.index >= train_cutoff) & (all_data_df.index < valid_cutoff)]
test_data = all_data_df[all_data_df.index >= valid_cutoff]

# Extract features and labels
def extract_features_labels(df):
    X = df.drop(columns=["Return", "Ranked_Return", "qid", "Ticker"]).values
    y = df["Ranked_Return"].values
    qid = df["qid"].values
    return X, y, qid

X_train, y_train, qid_train = extract_features_labels(train_data)
X_valid, y_valid, qid_valid = extract_features_labels(valid_data)
X_test, y_test, qid_test = extract_features_labels(test_data)

# Bootstrap sampling function
def bootstrap_sampling(X, y, qid, num_samples=10):
    N = X.shape[0]
    bootstrap_datasets = []
    for _ in range(num_samples):
        indices = np.random.choice(N, N, replace=True)  # Bootstrap sampling
        X_sample, y_sample, qid_sample = X[indices], y[indices], qid[indices]
        bootstrap_datasets.append((X_sample, y_sample, qid_sample))
    return bootstrap_datasets

# Generate bootstrap train sets
bootstrap_train_datasets = bootstrap_sampling(X_train, y_train, qid_train, num_samples=10)

# Save dataset
dataset = {
    "train": (X_train, y_train, qid_train),
    "bootstrap_train": bootstrap_train_datasets,
    "valid": (X_valid, y_valid, qid_valid),
    "test": (X_test, y_test, qid_test),
}
# Out:
# Processing Tickers: 100%|██████████| 1506/1506 [00:07<00:00, 197.41ticker/s]

# %%
import xgboost as xgb
import numpy as np

models = []  # Store all trained XGBRanker models
valid_scores = []  # Store the best NDCG scores on the validation set

X_valid, y_valid, qid_valid = dataset["valid"]  # Load validation set data

# Iterate over bootstrap-sampled training data
for i, (X_sample, y_sample, qid_sample) in enumerate(dataset["bootstrap_train"]):
    print(f"Training model {i+1} ...")

    # Initialize XGBRanker
    model = xgb.XGBRanker(
        objective="rank:pairwise",
        n_estimators=500,  # Set a sufficiently large n_estimators, allowing early stopping to determine the best iteration
        max_depth=4,
        learning_rate=0.1,
        subsample=0.8,
        eval_metric="ndcg",  
        colsample_bytree=0.8,
        early_stopping_rounds=20
    )
    
    # Train the model and use the validation data for early stopping
    model.fit(
        X_sample, y_sample, 
        group=np.bincount(qid_sample),  # Training group information
        eval_set=[(X_valid, y_valid)],  # Provide validation set
        eval_group=[np.bincount(qid_valid)],  # Validation set group information
        verbose=True
    )

    # Store the model and validation score
    models.append(model)
    valid_scores.append(model.best_score)  # best_score: XGBoost automatically records the best NDCG value
# Out:
# Training model 1 ...
# [0]	validation_0-ndcg:0.79338
# [1]	validation_0-ndcg:0.79520
# [2]	validation_0-ndcg:0.79396
# [3]	validation_0-ndcg:0.79691
# [4]	validation_0-ndcg:0.79937
# [5]	validation_0-ndcg:0.80202
# [6]	validation_0-ndcg:0.80166
# [7]	validation_0-ndcg:0.80017
# [8]	validation_0-ndcg:0.79970
# [9]	validation_0-ndcg:0.80086
# [10]	validation_0-ndcg:0.80062
# [11]	validation_0-ndcg:0.80307
# [12]	validation_0-ndcg:0.80293
# [13]	validation_0-ndcg:0.80340
# [14]	validation_0-ndcg:0.80341
# [15]	validation_0-ndcg:0.80432
# [16]	validation_0-ndcg:0.80411
# [17]	validation_0-ndcg:0.80561
# [18]	validation_0-ndcg:0.80579
# [19]	validation_0-ndcg:0.80558
# [20]	validation_0-ndcg:0.80542
# [21]	validation_0-ndcg:0.80585
# [22]	validation_0-ndcg:0.80491
# [23]	validation_0-ndcg:0.80675
# [24]	validation_0-ndcg:0.80714
# [25]	validation_0-ndcg:0.80652
# [26]	validation_0-ndcg:0.80721
# [27]	validation_0-ndcg:0.80748
# [28]	validation_0-ndcg:0.80879
# [29]	validation_0-ndcg:0.80779
# [30]	validation_0-ndcg:0.80757
# [31]	validation_0-ndcg:0.80760
# [32]	validation_0-ndcg:0.80735
# [33]	validation_0-ndcg:0.80863
# [34]	validation_0-ndcg:0.80817
# [35]	validation_0-ndcg:0.80950
# [36]	validation_0-ndcg:0.80844
# [37]	validation_0-ndcg:0.80849
# [38]	validation_0-ndcg:0.80761
# [39]	validation_0-ndcg:0.80742
# [40]	validation_0-ndcg:0.80782
# [41]	validation_0-ndcg:0.80730
# [42]	validation_0-ndcg:0.80880
# [43]	validation_0-ndcg:0.80964
# [44]	validation_0-ndcg:0.80936
# [45]	validation_0-ndcg:0.81036
# [46]	validation_0-ndcg:0.80973
# [47]	validation_0-ndcg:0.81050
# [48]	validation_0-ndcg:0.81010
# [49]	validation_0-ndcg:0.80900
# [50]	validation_0-ndcg:0.80936
# [51]	validation_0-ndcg:0.80853
# [52]	validation_0-ndcg:0.80800
# [53]	validation_0-ndcg:0.80771
# [54]	validation_0-ndcg:0.80839
# [55]	validation_0-ndcg:0.80862
# [56]	validation_0-ndcg:0.80987
# [57]	validation_0-ndcg:0.80798
# [58]	validation_0-ndcg:0.80841
# [59]	validation_0-ndcg:0.80845
# [60]	validation_0-ndcg:0.80824
# [61]	validation_0-ndcg:0.80868
# [62]	validation_0-ndcg:0.80885
# [63]	validation_0-ndcg:0.80723
# [64]	validation_0-ndcg:0.80707
# [65]	validation_0-ndcg:0.80752
# [66]	validation_0-ndcg:0.80709
# Training model 2 ...
# [0]	validation_0-ndcg:0.78765
# [1]	validation_0-ndcg:0.78864
# [2]	validation_0-ndcg:0.78676
# [3]	validation_0-ndcg:0.78360
# [4]	validation_0-ndcg:0.78732
# [5]	validation_0-ndcg:0.79127
# [6]	validation_0-ndcg:0.79104
# [7]	validation_0-ndcg:0.79316
# [8]	validation_0-ndcg:0.79389
# [9]	validation_0-ndcg:0.79521
# [10]	validation_0-ndcg:0.79544
# [11]	validation_0-ndcg:0.79681
# [12]	validation_0-ndcg:0.79605
# [13]	validation_0-ndcg:0.79702
# [14]	validation_0-ndcg:0.79920
# [15]	validation_0-ndcg:0.79940
# [16]	validation_0-ndcg:0.80206
# [17]	validation_0-ndcg:0.79981
# [18]	validation_0-ndcg:0.80028
# [19]	validation_0-ndcg:0.79933
# [20]	validation_0-ndcg:0.80133
# [21]	validation_0-ndcg:0.80054
# [22]	validation_0-ndcg:0.80016
# [23]	validation_0-ndcg:0.80320
# [24]	validation_0-ndcg:0.80267
# [25]	validation_0-ndcg:0.80314
# [26]	validation_0-ndcg:0.80215
# [27]	validation_0-ndcg:0.80221
# [28]	validation_0-ndcg:0.80219
# [29]	validation_0-ndcg:0.80274
# [30]	validation_0-ndcg:0.80328
# [31]	validation_0-ndcg:0.80420
# [32]	validation_0-ndcg:0.80336
# [33]	validation_0-ndcg:0.80390
# [34]	validation_0-ndcg:0.80471
# [35]	validation_0-ndcg:0.80386
# [36]	validation_0-ndcg:0.80366
# [37]	validation_0-ndcg:0.80359
# [38]	validation_0-ndcg:0.80301
# [39]	validation_0-ndcg:0.80363
# [40]	validation_0-ndcg:0.80340
# [41]	validation_0-ndcg:0.80319
# [42]	validation_0-ndcg:0.80265
# [43]	validation_0-ndcg:0.80288
# [44]	validation_0-ndcg:0.80293
# [45]	validation_0-ndcg:0.80261
# [46]	validation_0-ndcg:0.80169
# [47]	validation_0-ndcg:0.80134
# [48]	validation_0-ndcg:0.80077
# [49]	validation_0-ndcg:0.80099
# [50]	validation_0-ndcg:0.79948
# [51]	validation_0-ndcg:0.79973
# [52]	validation_0-ndcg:0.80071
# [53]	validation_0-ndcg:0.80075
# Training model 3 ...
# [0]	validation_0-ndcg:0.78432
# [1]	validation_0-ndcg:0.80223
# [2]	validation_0-ndcg:0.79923
# [3]	validation_0-ndcg:0.79843
# [4]	validation_0-ndcg:0.80040
# [5]	validation_0-ndcg:0.80040
# [6]	validation_0-ndcg:0.80213
# [7]	validation_0-ndcg:0.79898
# [8]	validation_0-ndcg:0.80137
# [9]	validation_0-ndcg:0.80089
# [10]	validation_0-ndcg:0.79885
# [11]	validation_0-ndcg:0.79811
# [12]	validation_0-ndcg:0.79875
# [13]	validation_0-ndcg:0.79829
# [14]	validation_0-ndcg:0.79820
# [15]	validation_0-ndcg:0.80029
# [16]	validation_0-ndcg:0.79904
# [17]	validation_0-ndcg:0.79871
# [18]	validation_0-ndcg:0.79911
# [19]	validation_0-ndcg:0.79911
# [20]	validation_0-ndcg:0.80043
# [21]	validation_0-ndcg:0.80014
# Training model 4 ...
# [0]	validation_0-ndcg:0.80067
# [1]	validation_0-ndcg:0.80091
# [2]	validation_0-ndcg:0.80239
# [3]	validation_0-ndcg:0.80482
# [4]	validation_0-ndcg:0.80340
# [5]	validation_0-ndcg:0.80379
# [6]	validation_0-ndcg:0.80372
# [7]	validation_0-ndcg:0.80590
# [8]	validation_0-ndcg:0.80588
# [9]	validation_0-ndcg:0.80638
# [10]	validation_0-ndcg:0.80868
# [11]	validation_0-ndcg:0.80795
# [12]	validation_0-ndcg:0.80816
# [13]	validation_0-ndcg:0.80765
# [14]	validation_0-ndcg:0.80783
# [15]	validation_0-ndcg:0.80788
# [16]	validation_0-ndcg:0.80763
# [17]	validation_0-ndcg:0.80676
# [18]	validation_0-ndcg:0.80810
# [19]	validation_0-ndcg:0.80876
# [20]	validation_0-ndcg:0.80961
# [21]	validation_0-ndcg:0.80865
# [22]	validation_0-ndcg:0.80758
# [23]	validation_0-ndcg:0.80805
# [24]	validation_0-ndcg:0.80890
# [25]	validation_0-ndcg:0.80861
# [26]	validation_0-ndcg:0.80869
# [27]	validation_0-ndcg:0.80804
# [28]	validation_0-ndcg:0.80861
# [29]	validation_0-ndcg:0.80846
# [30]	validation_0-ndcg:0.80803
# [31]	validation_0-ndcg:0.80894
# [32]	validation_0-ndcg:0.80891
# [33]	validation_0-ndcg:0.80881
# [34]	validation_0-ndcg:0.80890
# [35]	validation_0-ndcg:0.80800
# [36]	validation_0-ndcg:0.80800
# [37]	validation_0-ndcg:0.80794
# [38]	validation_0-ndcg:0.80707
# [39]	validation_0-ndcg:0.80734
# [40]	validation_0-ndcg:0.80715
# Training model 5 ...
# [0]	validation_0-ndcg:0.78816
# [1]	validation_0-ndcg:0.79341
# [2]	validation_0-ndcg:0.79929
# [3]	validation_0-ndcg:0.79910
# [4]	validation_0-ndcg:0.80054
# [5]	validation_0-ndcg:0.79733
# [6]	validation_0-ndcg:0.79551
# [7]	validation_0-ndcg:0.79892
# [8]	validation_0-ndcg:0.79854
# [9]	validation_0-ndcg:0.79749
# [10]	validation_0-ndcg:0.80267
# [11]	validation_0-ndcg:0.80336
# [12]	validation_0-ndcg:0.80258
# [13]	validation_0-ndcg:0.80208
# [14]	validation_0-ndcg:0.80329
# [15]	validation_0-ndcg:0.80439
# [16]	validation_0-ndcg:0.80387
# [17]	validation_0-ndcg:0.80567
# [18]	validation_0-ndcg:0.80519
# [19]	validation_0-ndcg:0.80476
# [20]	validation_0-ndcg:0.80553
# [21]	validation_0-ndcg:0.80468
# [22]	validation_0-ndcg:0.80528
# [23]	validation_0-ndcg:0.80630
# [24]	validation_0-ndcg:0.80468
# [25]	validation_0-ndcg:0.80519
# [26]	validation_0-ndcg:0.80486
# [27]	validation_0-ndcg:0.80467
# [28]	validation_0-ndcg:0.80426
# [29]	validation_0-ndcg:0.80565
# [30]	validation_0-ndcg:0.80574
# [31]	validation_0-ndcg:0.80744
# [32]	validation_0-ndcg:0.80508
# [33]	validation_0-ndcg:0.80620
# [34]	validation_0-ndcg:0.80909
# [35]	validation_0-ndcg:0.81023
# [36]	validation_0-ndcg:0.80865
# [37]	validation_0-ndcg:0.80866
# [38]	validation_0-ndcg:0.80922
# [39]	validation_0-ndcg:0.80829
# [40]	validation_0-ndcg:0.80895
# [41]	validation_0-ndcg:0.80844
# [42]	validation_0-ndcg:0.80860
# [43]	validation_0-ndcg:0.80830
# [44]	validation_0-ndcg:0.80853
# [45]	validation_0-ndcg:0.80838
# [46]	validation_0-ndcg:0.80821
# [47]	validation_0-ndcg:0.80770
# [48]	validation_0-ndcg:0.80611
# [49]	validation_0-ndcg:0.80597
# [50]	validation_0-ndcg:0.80487
# [51]	validation_0-ndcg:0.80508
# [52]	validation_0-ndcg:0.80607
# [53]	validation_0-ndcg:0.80662
# [54]	validation_0-ndcg:0.80900
# Training model 6 ...
# [0]	validation_0-ndcg:0.79339
# [1]	validation_0-ndcg:0.79782
# [2]	validation_0-ndcg:0.79417
# [3]	validation_0-ndcg:0.79695
# [4]	validation_0-ndcg:0.80087
# [5]	validation_0-ndcg:0.80149
# [6]	validation_0-ndcg:0.80101
# [7]	validation_0-ndcg:0.80216
# [8]	validation_0-ndcg:0.80069
# [9]	validation_0-ndcg:0.79921
# [10]	validation_0-ndcg:0.79890
# [11]	validation_0-ndcg:0.79939
# [12]	validation_0-ndcg:0.79858
# [13]	validation_0-ndcg:0.79955
# [14]	validation_0-ndcg:0.79935
# [15]	validation_0-ndcg:0.80035
# [16]	validation_0-ndcg:0.80130
# [17]	validation_0-ndcg:0.80221
# [18]	validation_0-ndcg:0.80098
# [19]	validation_0-ndcg:0.80047
# [20]	validation_0-ndcg:0.80001
# [21]	validation_0-ndcg:0.80080
# [22]	validation_0-ndcg:0.80038
# [23]	validation_0-ndcg:0.80031
# [24]	validation_0-ndcg:0.80035
# [25]	validation_0-ndcg:0.79983
# [26]	validation_0-ndcg:0.79989
# [27]	validation_0-ndcg:0.79985
# [28]	validation_0-ndcg:0.79987
# [29]	validation_0-ndcg:0.80038
# [30]	validation_0-ndcg:0.79979
# [31]	validation_0-ndcg:0.79946
# [32]	validation_0-ndcg:0.79940
# [33]	validation_0-ndcg:0.79977
# [34]	validation_0-ndcg:0.79891
# [35]	validation_0-ndcg:0.80023
# [36]	validation_0-ndcg:0.80019
# Training model 7 ...
# [0]	validation_0-ndcg:0.79652
# [1]	validation_0-ndcg:0.79874
# [2]	validation_0-ndcg:0.80292
# [3]	validation_0-ndcg:0.80351
# [4]	validation_0-ndcg:0.80047
# [5]	validation_0-ndcg:0.80590
# [6]	validation_0-ndcg:0.80404
# [7]	validation_0-ndcg:0.80452
# [8]	validation_0-ndcg:0.80400
# [9]	validation_0-ndcg:0.80418
# [10]	validation_0-ndcg:0.80490
# [11]	validation_0-ndcg:0.80390
# [12]	validation_0-ndcg:0.80413
# [13]	validation_0-ndcg:0.80501
# [14]	validation_0-ndcg:0.80506
# [15]	validation_0-ndcg:0.80522
# [16]	validation_0-ndcg:0.80323
# [17]	validation_0-ndcg:0.80507
# [18]	validation_0-ndcg:0.80341
# [19]	validation_0-ndcg:0.80320
# [20]	validation_0-ndcg:0.80278
# [21]	validation_0-ndcg:0.80309
# [22]	validation_0-ndcg:0.80302
# [23]	validation_0-ndcg:0.80426
# [24]	validation_0-ndcg:0.80315
# Training model 8 ...
# [0]	validation_0-ndcg:0.79075
# [1]	validation_0-ndcg:0.79808
# [2]	validation_0-ndcg:0.79886
# [3]	validation_0-ndcg:0.79673
# [4]	validation_0-ndcg:0.79470
# [5]	validation_0-ndcg:0.79111
# [6]	validation_0-ndcg:0.79060
# [7]	validation_0-ndcg:0.79150
# [8]	validation_0-ndcg:0.79480
# [9]	validation_0-ndcg:0.79552
# [10]	validation_0-ndcg:0.79511
# [11]	validation_0-ndcg:0.79461
# [12]	validation_0-ndcg:0.79677
# [13]	validation_0-ndcg:0.79628
# [14]	validation_0-ndcg:0.79717
# [15]	validation_0-ndcg:0.79657
# [16]	validation_0-ndcg:0.79744
# [17]	validation_0-ndcg:0.79775
# [18]	validation_0-ndcg:0.79829
# [19]	validation_0-ndcg:0.79759
# [20]	validation_0-ndcg:0.79760
# [21]	validation_0-ndcg:0.79652
# [22]	validation_0-ndcg:0.79703
# Training model 9 ...
# [0]	validation_0-ndcg:0.79470
# [1]	validation_0-ndcg:0.80441
# [2]	validation_0-ndcg:0.80478
# [3]	validation_0-ndcg:0.80354
# [4]	validation_0-ndcg:0.80278
# [5]	validation_0-ndcg:0.80450
# [6]	validation_0-ndcg:0.80572
# [7]	validation_0-ndcg:0.80371
# [8]	validation_0-ndcg:0.80307
# [9]	validation_0-ndcg:0.80276
# [10]	validation_0-ndcg:0.80192
# [11]	validation_0-ndcg:0.80068
# [12]	validation_0-ndcg:0.79929
# [13]	validation_0-ndcg:0.80019
# [14]	validation_0-ndcg:0.79988
# [15]	validation_0-ndcg:0.80122
# [16]	validation_0-ndcg:0.80115
# [17]	validation_0-ndcg:0.80154
# [18]	validation_0-ndcg:0.80016
# [19]	validation_0-ndcg:0.79980
# [20]	validation_0-ndcg:0.79948
# [21]	validation_0-ndcg:0.79943
# [22]	validation_0-ndcg:0.80003
# [23]	validation_0-ndcg:0.79970
# [24]	validation_0-ndcg:0.80149
# [25]	validation_0-ndcg:0.80162
# Training model 10 ...
# [0]	validation_0-ndcg:0.79850
# [1]	validation_0-ndcg:0.80130
# [2]	validation_0-ndcg:0.80343
# [3]	validation_0-ndcg:0.79802
# [4]	validation_0-ndcg:0.79950
# [5]	validation_0-ndcg:0.80219
# [6]	validation_0-ndcg:0.80653
# [7]	validation_0-ndcg:0.80608
# [8]	validation_0-ndcg:0.80734
# [9]	validation_0-ndcg:0.80831
# [10]	validation_0-ndcg:0.80885
# [11]	validation_0-ndcg:0.80985
# [12]	validation_0-ndcg:0.81006
# [13]	validation_0-ndcg:0.80903
# [14]	validation_0-ndcg:0.80795
# [15]	validation_0-ndcg:0.80492
# [16]	validation_0-ndcg:0.80666
# [17]	validation_0-ndcg:0.80755
# [18]	validation_0-ndcg:0.80684
# [19]	validation_0-ndcg:0.80637
# [20]	validation_0-ndcg:0.80634
# [21]	validation_0-ndcg:0.80623
# [22]	validation_0-ndcg:0.80823
# [23]	validation_0-ndcg:0.80740
# [24]	validation_0-ndcg:0.80720
# [25]	validation_0-ndcg:0.80807
# [26]	validation_0-ndcg:0.80773
# [27]	validation_0-ndcg:0.80889
# [28]	validation_0-ndcg:0.80811
# [29]	validation_0-ndcg:0.80753
# [30]	validation_0-ndcg:0.80825
# [31]	validation_0-ndcg:0.80911
# [32]	validation_0-ndcg:0.80967

# %%
import numpy as np
from sklearn.metrics import ndcg_score

# Load test dataset
X_test, y_test, qid_test = dataset["test"]

test_preds = np.zeros((len(models), len(X_test)))  # Store predictions from all models

# Iterate through all bootstrap-trained models
for i, model in enumerate(models):
    test_preds[i, :] = model.predict(X_test)

# Compute the final ensemble prediction (using the mean)
final_test_preds = np.mean(test_preds, axis=0) 

# Create a DataFrame to store predictions
predictions = pd.DataFrame({
    "qid": qid_test,
    "y_true": y_test,
    "y_pred": final_test_preds
}).sort_values(by="qid")


def compute_saber_scores(rank_lists):
    """
    Compute SABER ranking scores (combining rankings from multiple models).
    """
    mean_rank = np.mean(rank_lists, axis=0)  # Compute mean ranking across all models
    std_rank = np.std(rank_lists, axis=0)  # Compute ranking standard deviation
    saber_scores = 1 / (mean_rank * (std_rank + 1e-6))  # Avoid division by zero
    return saber_scores

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import ndcg_score

# Load test dataset
X_test, y_test, qid_test = dataset["test"]

test_preds = np.zeros((len(models), len(X_test)))  # Store predictions from all models

# Iterate over all bootstrap-trained models
for i, model in enumerate(models):
    test_preds[i, :] = model.predict(X_test)  # Predictions from each model

# **Step 1: Compute rankings within each trading day (qid)**
rank_lists = np.zeros_like(test_preds)

for i in range(len(models)):  # Iterate over all models
    for qid in np.unique(qid_test):  # Iterate over all trading days
        mask = qid_test == qid  # Select data for the current trading day
        if np.sum(mask) > 1:  # Ensure there is data for the day
            rank_lists[i, mask] = np.argsort(np.argsort(-test_preds[i, mask]))  # Compute rankings within the day

# **Step 2: Compute SABER scores**
def compute_saber_scores(rank_lists):
    """
    Compute SABER long and short ranking scores.
    """
    mean_rank = np.mean(rank_lists, axis=0)  # Compute the average ranking across all models
    std_rank = np.std(rank_lists, axis=0)  # Compute the standard deviation of rankings
    
    saber_long = 1 / (mean_rank * (std_rank + 1e-6))  # Long strategy: higher and stable ranking
    saber_short = mean_rank / (std_rank + 1e-6)  # Short strategy: lower and stable ranking
    
    return saber_long, saber_short

saber_long, saber_short = compute_saber_scores(rank_lists)  # Compute long & short scores

# **Create a DataFrame to store final rankings**
predictions = pd.DataFrame({
    "qid": qid_test,  # Trading date
    "y_true": y_test,  # True ranking
    "saber_long": saber_long,  # Long strategy score
    "saber_short": saber_short  # Short strategy score
}).sort_values(by=["qid", "saber_long"], ascending=[True, False])  # Sort by day and descending long score

# **Step 4: Compute daily NDCG scores**
ndcg_long_scores = []
ndcg_short_scores = []

for qid in predictions["qid"].unique():
    daily_data = predictions[predictions["qid"] == qid]  # Select data for the day
    if len(daily_data) > 1:
        ndcg_long = ndcg_score([daily_data["y_true"].values], [daily_data["saber_long"].values])
        ndcg_short = ndcg_score([daily_data["y_true"].values], [-daily_data["saber_short"].values])  # Negative for short ranking
        ndcg_long_scores.append(ndcg_long)
        ndcg_short_scores.append(ndcg_short)

# Compute the average NDCG across all days
final_ndcg_long = np.mean(ndcg_long_scores)
final_ndcg_short = np.mean(ndcg_short_scores)

print(f"Ensemble SABER Long Strategy NDCG: {final_ndcg_long:.4f}")
print(f"Ensemble SABER Short Strategy NDCG: {final_ndcg_short:.4f}")
# Out:
# Ensemble SABER Long Strategy NDCG: 0.8848
# Ensemble SABER Short Strategy NDCG: 0.8849

# %%
predictions
# Out:
#        qid  y_true  saber_long  saber_short
# 212    143       4  0.00176315   1.15550006
# 259    143       0  0.00151402   1.19548489
# 610    143       4  0.00075072   1.44679764
# 424    143       3  0.00027780   1.62999382
# 715    143       1  0.00022000   1.39746943
# ...    ...     ...         ...          ...
# 73221  227       2  0.00000605   2.57131768
# 73171  227       1  0.00000604   2.83300566
# 73027  227       1  0.00000601   2.80826801
# 73261  227       2  0.00000598   2.28802981
# 73443  227       2  0.00000562   2.14238719
#
# [73798 rows x 4 columns]

# %%
test_data_selected = test_data.reset_index()[["date", "qid", "Ticker", "Return"]]
predictions['return_true'] = test_data_selected['Return']
predictions["date"] = test_data_selected['date']

# %%
predictions
# Out:
#        qid  y_true  saber_long  saber_short  return_true       date
# 212    143       4  0.00176315   1.15550006   0.08808290 2018-01-31
# 259    143       0  0.00151402   1.19548489  -0.17123288 2018-01-31
# 610    143       4  0.00075072   1.44679764   0.42708334 2018-01-31
# 424    143       3  0.00027780   1.62999382   0.00000000 2018-01-31
# 715    143       1  0.00022000   1.39746943  -0.06712274 2018-01-31
# ...    ...     ...         ...          ...          ...        ...
# 73221  227       2  0.00000605   2.57131768  -0.00968950 2025-01-31
# 73171  227       1  0.00000604   2.83300566  -0.05042373 2025-01-31
# 73027  227       1  0.00000601   2.80826801  -0.05425876 2025-01-31
# 73261  227       2  0.00000598   2.28802981  -0.04273302 2025-01-31
# 73443  227       2  0.00000562   2.14238719  -0.03443358 2025-01-31
#
# [73798 rows x 6 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Set parameters
top_k = 10
position_size = 1 / (top_k * 2) 
risk_free_rate = 0.00

# Copy predictions DataFrame
df = predictions.copy()

# **Sort by `qid` (to maintain chronological order)**
df = df.sort_values(by=["qid"])

# **LTR Strategy**
# Step 1: Rank stocks within each `qid` based on SABER ranking
df["rank_long"] = df.groupby("qid")["saber_long"].rank(ascending=False, method="first")  # Rank for long positions (descending)
df["rank_short"] = df.groupby("qid")["saber_short"].rank(ascending=False, method="first")  # Rank for short positions (descending)

# Step 2: Select long and short positions based on SABER ranking
df["long"] = (df["rank_long"] <= top_k).astype(int)  # Select long positions
df["short"] = (df["rank_short"] <= top_k).astype(int)  # Select short positions

# Step 3: Compute returns for long and short positions
df["long_return"] = df["long"] * df["return_true"]
df["short_return"] = -df["short"] * df["return_true"]  # Short positions have negative returns

# Step 4: Compute daily strategy returns
df["ltr_strategy_return"] = position_size * (df["long_return"] + df["short_return"])

# **Random Strategy**
df["random_long"] = df.groupby("qid")["saber_long"].transform(
    lambda x: np.random.choice([1, 0], size=len(x), p=[top_k / len(x), 1 - top_k / len(x)]))
df["random_short"] = df.groupby("qid")["saber_short"].transform(
    lambda x: np.random.choice([1, 0], size=len(x), p=[top_k / len(x), 1 - top_k / len(x)]))

df["random_long_return"] = df["random_long"] * df["return_true"]
df["random_short_return"] = -df["random_short"] * df["return_true"]

df["random_strategy_return"] = position_size * (df["random_long_return"] + df["random_short_return"])

# **Compute cumulative returns**
monthly_pnl_ltr = df.groupby("date")["ltr_strategy_return"].sum()
monthly_pnl_random = df.groupby("date")["random_strategy_return"].sum()

cumulative_pnl_ltr = monthly_pnl_ltr.cumsum()
cumulative_pnl_random = monthly_pnl_random.cumsum()

# **Compute performance metrics**
def compute_metrics(monthly_pnl, label):
    mean_return = monthly_pnl.mean() * 12  # Annualized return
    std_dev = monthly_pnl.std() * np.sqrt(12)  # Annualized volatility
    sharpe_ratio = (mean_return - risk_free_rate) / std_dev if std_dev != 0 else np.nan
    return {
        "Strategy": label,
        "Annualized Return": mean_return,
        "Annualized Volatility": std_dev,
        "Sharpe Ratio": sharpe_ratio
    }

ltr_metrics = compute_metrics(monthly_pnl_ltr, "LTR Strategy (SABER)")
random_metrics = compute_metrics(monthly_pnl_random, "Random Strategy")

performance_df = pd.DataFrame([ltr_metrics, random_metrics])

# **Plot cumulative returns**
plt.figure(figsize=(12, 6))
cumulative_pnl_ltr.plot(label="LTR Strategy (SABER)", linewidth=2)
cumulative_pnl_random.plot(label="Random Strategy", linewidth=2, linestyle="dashed")

plt.axhline(y=0, color="black", linestyle="--", alpha=0.8)
plt.xlabel("Time (qid)")
plt.ylabel("Cumulative P&L")
plt.title("LTR Strategy (SABER) vs. Random Strategy Cumulative P&L")
plt.legend()
plt.grid()
plt.show()

# %%
df["prev_long"] = df.groupby("qid")["long"].shift(1).fillna(0)  # Previous period (last month) long positions
df["prev_short"] = df.groupby("qid")["short"].shift(1).fillna(0)  # Previous period (last month) short positions

# **Step 1: Compute previous total holdings**
df["prev_total_holdings"] = df["prev_long"] + df["prev_short"]  # Total positions in the previous period

# **Step 2: Compute absolute position changes**
df["turnover_ltr_abs"] = ((df["long"] - df["prev_long"]).abs() + (df["short"] - df["prev_short"]).abs())/2

# **Step 3: Compute monthly turnover**
monthly_turnover_ltr = df.groupby("date")[["turnover_ltr_abs", "prev_total_holdings"]].sum()  # Sum across all stocks
monthly_turnover_ltr["turnover_rate"] = np.where(monthly_turnover_ltr["prev_total_holdings"] > 0,
                                                 monthly_turnover_ltr["turnover_ltr_abs"] / monthly_turnover_ltr["prev_total_holdings"],
                                                 0)  # Avoid division by zero

# **Step 4: Compute the average monthly turnover rate**
avg_turnover_ltr = monthly_turnover_ltr["turnover_rate"].mean()

df["prev_random_long"] = df.groupby("qid")["random_long"].shift(1).fillna(0)  # Previous period (last month) long positions
df["prev_random_short"] = df.groupby("qid")["random_short"].shift(1).fillna(0)  # Previous period (last month) short positions

# **Repeat for random strategy**
df["prev_total_holdings_random"] = df["prev_random_long"] + df["prev_random_short"]
df["turnover_random_abs"] = ((df["random_long"] - df["prev_random_long"]).abs() + (df["random_short"] - df["prev_random_short"]).abs())/2

monthly_turnover_random = df.groupby("date")[["turnover_random_abs", "prev_total_holdings_random"]].sum()
monthly_turnover_random["turnover_rate"] = np.where(monthly_turnover_random["prev_total_holdings_random"] > 0,
                                                    monthly_turnover_random["turnover_random_abs"] / monthly_turnover_random["prev_total_holdings_random"],
                                                    0)

avg_turnover_random = monthly_turnover_random["turnover_rate"].mean()

# %%
# **Plot turnover rate over time**
plt.figure(figsize=(12, 6))
monthly_turnover_ltr["turnover_rate"].plot(label="LTR Strategy (SABER)", linewidth=2)
monthly_turnover_random["turnover_rate"].plot(label="Random Strategy", linewidth=2, linestyle="dashed")

plt.xlabel("Time (qid)")
plt.ylabel("Turnover Rate")
plt.title("Turnover Rate Comparison: LTR vs. Random Strategy")
plt.legend()
plt.grid()
plt.show()

# %%
performance_df
# Out:
#                Strategy  Annualized Return  Annualized Volatility  \
# 0  LTR Strategy (SABER)         0.30355574             0.16936501
# 1       Random Strategy        -0.00804535             0.09100678
#
#    Sharpe Ratio
# 0    1.79231670
# 1   -0.08840390
