# %%
from technical_features import BuildFeatures

# %%
obj=BuildFeatures('MSFT')
obj.build_technical_features()

# %%
display(obj.technical_features.tail(10),)
# Out:
#                            Doji_Star  Dragonfly_Doji  Engulfing_Pattern  \
# Date
# 2025-01-10 00:00:00-05:00          0               0               -100
# 2025-01-13 00:00:00-05:00          0               0                  0
# 2025-01-14 00:00:00-05:00          0               0                  0
# 2025-01-15 00:00:00-05:00          0               0                  0
# 2025-01-16 00:00:00-05:00          0               0                  0
# 2025-01-17 00:00:00-05:00          0               0                  0
# 2025-01-21 00:00:00-05:00          0               0                  0
# 2025-01-22 00:00:00-05:00          0               0                  0
# 2025-01-23 00:00:00-05:00          0               0                  0
# 2025-01-24 00:00:00-05:00          0               0                  0
#
#                            Evening_Doji_Star  Evening_Star  \
# Date
# 2025-01-10 00:00:00-05:00                  0             0
# ...

# %%
print(obj.stock)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1986-03-13 00:00:00-05:00    0.054485    0.062498    0.054485    0.059827
# 1986-03-14 00:00:00-05:00    0.059827    0.063032    0.059827    0.061963
# 1986-03-17 00:00:00-05:00    0.061963    0.063566    0.061963    0.063032
# 1986-03-18 00:00:00-05:00    0.063032    0.063566    0.060895    0.061429
# 1986-03-19 00:00:00-05:00    0.061429    0.061963    0.059827    0.060361
# ...                               ...         ...         ...         ...
# 2025-01-17 00:00:00-05:00  434.089996  434.480011  428.170013  429.029999
# 2025-01-21 00:00:00-05:00  430.200012  430.899994  425.600006  428.500000
# 2025-01-22 00:00:00-05:00  437.559998  447.269989  436.000000  446.200012
# 2025-01-23 00:00:00-05:00  442.000000  446.750000  441.500000  446.709991
# 2025-01-24 00:00:00-05:00  445.160004  446.649994  441.399994  444.059998
#
#                                Volume  Dividends  Stock Splits
# Date
# ...
